# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# # Check the folder
# !ls

# # I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

# #Compile Darknet
#!make

##Copies the Darknet compiled version to Google drive
#!cp ./darknet /content/drive/MyDrive/darknet/darknet

# %%
# Uncomment after the first run, when you have a copy of compiled darkent in your Google Drive

# Makes a dir for darknet and move there
# !mkdir darknet
# %cd darknet

# Copy the Darkent compiled version to the VM local drive
# !cp /content/drive/MyDrive/darknet/bin/darknet ./darknet

# Set execution permissions to Darknet
# !chmod +x ./darknet
# Out:
# /content/darknet

# %%
# !ln -s /content/drive/MyDrive/darknet/inria_psu_backup /content/darknet/inria_psu_backup

# %%
# !unzip "/content/drive/MyDrive/darknet/inria_psu_data.zip" -d "/content/darknet"
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: /content/darknet/data/Train/00000131a.png
#   inflating: /content/darknet/data/Train/00000476a.png
#  extracting: /content/darknet/data/Train/dsc00677.txt
#   inflating: /content/darknet/data/Train/00000675a.png
#   inflating: /content/darknet/data/Train/00000090a.png
#   inflating: /content/darknet/data/Train/person001010.jpg
#  extracting: /content/darknet/data/Train/no_person__no_bike_062.txt
#  extracting: /content/darknet/data/Train/image000414.txt
#   inflating: /content/darknet/data/Train/person000669.jpg
#   inflating: /content/darknet/data/Train/D2004-07-06_14h56m34s.jpg
#   inflating: /content/darknet/data/Train/person_286.txt
#   inflating: /content/darknet/data/Train/D2004-08-17_14h31m13s.jpg
#  extracting: /content/darknet/data/Train/image000063.txt
#   inflating: /content/darknet/data/Train/image000422.jpg
#   inflating: /content/darknet/data/Train/00000726a.png
# ...

# %%
# Do inicio
# %cd /content/darknet
# !./darknet detector train "/content/drive/MyDrive/darknet/inria_psu_data/inria_psu.data" "/content/drive/MyDrive/darknet/yolo-inria.cfg" "/content/drive/MyDrive/darknet/darknet53.conv.74"   -dont_show  | tee training.log
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  seconds
#
#  5815: 0.480044, 0.613773 avg loss, 0.000010 rate, 3.945107 seconds, 372160 images
# Loaded: 0.000045 seconds
#
# ...

# %%
# Continuar 
# %cd /content/darknet
# !./darknet detector train "/content/drive/MyDrive/darknet/inria_psu_data/inria_psu.data" "/content/drive/MyDrive/darknet/yolo-inria.cfg" "/content/drive/MyDrive/darknet/inria_psu_backup/yolo-inria_last.weights"   -dont_show  | tee training.log
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#  19069: 0.525000, 0.594139 avg loss, 0.000010 rate, 2.727333 seconds, 1220416 images
# Loaded: 0.000045 seconds
#
#  19070: 0.653503, 0.600075 avg loss, 0.000010 rate, 2.738030 seconds, 1220480 images
# Resizing
# 288 x 288
#  try to allocate additional workspace_size = 69.05 MB
#  CUDA allocate done!
# Loaded: 0.384363 seconds
#
#  19071: 0.458329, 0.585901 avg loss, 0.000010 rate, 3.593965 seconds, 1220544 images
# Loaded: 0.000049 seconds
#
#  19072: 0.349895, 0.562300 avg loss, 0.000010 rate, 3.623294 seconds, 1220608 images
# Loaded: 0.000035 seconds
#
#  19073: 0.604990, 0.566569 avg loss, 0.000010 rate, 3.617762 seconds, 1220672 images
# Loaded: 0.000039 seconds
#
#  19074: 0.988008, 0.608713 avg loss, 0.000010 rate, 3.665256 seconds, 1220736 images
# Loaded: 0.000035 seconds
#
#  19075: 0.679263, 0.615768 avg loss, 0.000010 rate, 3.648648 seconds, 1220800 images
# Loaded: 0.000039 seconds
#
# ...

# %%
# copy pre-trained weight from your Drive to folder darknet
# !cp /content/drive/'My Drive'/yolo/yolov3_900.weights /content/darknet
# Out:
# cp: cannot stat '/content/drive/My Drive/YOLOv3_files/yolov3_900.weights': No such file or directory

# %%
# %cd /content/darknet
# !./darknet detector valid "/content/drive/MyDrive/darknet/data/inria.data" "/content/drive/MyDrive/darknet/yolo-inria.cfg" "/content/drive/MyDrive/darknet/backup/yolo-inria_final.weights"
# Out:
# /content/darknet
# results: Using default 'results'
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   320 x 320 x   3   ->   320 x 320 x  32 0.177 BF
#    1 conv     64  3 x 3 / 2   320 x 320 x  32   ->   160 x 160 x  64 0.944 BF
#    2 conv     32  1 x 1 / 1   160 x 160 x  64   ->   160 x 160 x  32 0.105 BF
#    3 conv     64  3 x 3 / 1   160 x 160 x  32   ->   160 x 160 x  64 0.944 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   160 x 160 x  64   ->    80 x  80 x 128 0.944 BF
#    6 conv     64  1 x 1 / 1    80 x  80 x 128   ->    80 x  80 x  64 0.105 BF
#    7 conv    128  3 x 3 / 1    80 x  80 x  64   ->    80 x  80 x 128 0.944 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1    80 x  80 x 128   ->    80 x  80 x  64 0.105 BF
#   10 conv    128  3 x 3 / 1    80 x  80 x  64   ->    80 x  80 x 128 0.944 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2    80 x  80 x 128   ->    40 x  40 x 256 0.944 BF
# ...
